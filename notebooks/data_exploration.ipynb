# %%
import pandas as pd

df = pd.read_csv("../data/raw/2017-07-05_Seat_Leon_RT_S_Stau.csv")

df.head()
# Out:
#            Time  Engine Coolant Temperature [Â°C]  \
# 0  07:16:30.444                                31
# 1  07:16:30.535                                31
# 2  07:16:30.625                                31
# 3  07:16:30.716                                31
# 4  07:16:30.814                                31
#
#    Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# 0                                      NaN               NaN
# 1                                     96.0               NaN
# 2                                     96.0               0.0
# 3                                     96.0               0.0
# 4                                     96.0               0.0
#
#    Vehicle Speed Sensor [km/h]  Intake Air Temperature [Â°C]  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.columns.tolist()
# Out:
# Rows: 46349
# Columns: 11
# ['Time',
#  'Engine Coolant Temperature [Â°C]',
#  'Intake Manifold Absolute Pressure [kPa]',
#  'Engine RPM [RPM]',
#  'Vehicle Speed Sensor [km/h]',
#  'Intake Air Temperature [Â°C]',
#  'Air Flow Rate from Mass Flow Sensor [g/s]',
#  'Absolute Throttle Position [%]',
#  'Ambient Air Temperature [Â°C]',
#  'Accelerator Pedal Position D [%]',
#  'Accelerator Pedal Position E [%]']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46349 entries, 0 to 46348
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Time                                       46349 non-null  str
#  1   Engine Coolant Temperature [Â°C]           46349 non-null  int64
#  2   Intake Manifold Absolute Pressure [kPa]    46348 non-null  float64
#  3   Engine RPM [RPM]                           46347 non-null  float64
#  4   Vehicle Speed Sensor [km/h]                46346 non-null  float64
#  5   Intake Air Temperature [Â°C]               46345 non-null  float64
#  6   Air Flow Rate from Mass Flow Sensor [g/s]  46344 non-null  float64
#  7   Absolute Throttle Position [%]             46343 non-null  float64
#  8   Ambient Air Temperature [Â°C]              46342 non-null  float64
#  9   Accelerator Pedal Position D [%]           46341 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Engine Coolant Temperature [Â°C]  \
# count                      46349.000000
# mean                          84.906017
# std                           14.497587
# min                           29.000000
# 25%                           90.000000
# 50%                           90.000000
# 75%                           91.000000
# max                           94.000000
#
#        Intake Manifold Absolute Pressure [kPa]  Engine RPM [RPM]  \
# count                             46348.000000      46347.000000
# mean                                117.672564       1378.157874
# std                                  24.173883        442.663154
# min                                  36.000000          0.000000
# 25%                                 103.000000       1054.000000
# 50%                                 109.000000       1443.000000
# 75%                                 123.000000       1689.000000
# max                                 231.000000       2689.000000
#
# ...

# %%
missing = df.isnull().sum()

missing
# Out:
# Time                                         0
# Engine Coolant Temperature [Â°C]             0
# Intake Manifold Absolute Pressure [kPa]      1
# Engine RPM [RPM]                             2
# Vehicle Speed Sensor [km/h]                  3
# Intake Air Temperature [Â°C]                 4
# Air Flow Rate from Mass Flow Sensor [g/s]    5
# Absolute Throttle Position [%]               6
# Ambient Air Temperature [Â°C]                7
# Accelerator Pedal Position D [%]             8
# Accelerator Pedal Position E [%]             9
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage
# Out:
# Time                                         0.000000
# Engine Coolant Temperature [Â°C]             0.000000
# Intake Manifold Absolute Pressure [kPa]      0.002158
# Engine RPM [RPM]                             0.004315
# Vehicle Speed Sensor [km/h]                  0.006473
# Intake Air Temperature [Â°C]                 0.008630
# Air Flow Rate from Mass Flow Sensor [g/s]    0.010788
# Absolute Throttle Position [%]               0.012945
# Ambient Air Temperature [Â°C]                0.015103
# Accelerator Pedal Position D [%]             0.017260
# Accelerator Pedal Position E [%]             0.019418
# dtype: float64

# %%
df.nunique()
# Out:
# Time                                         46349
# Engine Coolant Temperature [Â°C]                66
# Intake Manifold Absolute Pressure [kPa]        147
# Engine RPM [RPM]                              1221
# Vehicle Speed Sensor [km/h]                    127
# Intake Air Temperature [Â°C]                   115
# Air Flow Rate from Mass Flow Sensor [g/s]     1208
# Absolute Throttle Position [%]                  44
# Ambient Air Temperature [Â°C]                    8
# Accelerator Pedal Position D [%]               122
# Accelerator Pedal Position E [%]               124
# dtype: int64

# %%
from pathlib import Path

files = list(Path("../data/raw").glob("*.csv"))

for f in files[:20]:
    print(f.name)
# Out:
# 2018-03-01_Seat_Leon_RT_S_Normal.csv
# 2017-07-11_Seat_Leon_S_RT_Frei.csv
# 2017-07-14_Seat_Leon_KA_KA_Frei.csv
# 2017-08-07_Seat_Leon_KA_RT_Frei.csv
# 2018-03-23_Seat_Leon_S_RT_Stau.csv
# 2017-08-05_Seat_Leon_S_CW_Normal.csv
# 2018-03-19_Seat_Leon_RT_KA_Normal.csv
# 2018-02-26_Seat_Leon_RT_KA_Normal.csv
# 2017-07-26_Seat_Leon_S_KA_Normal.csv
# 2017-08-10_Seat_Leon_S_RT_Frei.csv
# 2017-07-24_Seat_Leon_RT_KA_Normal.csv
# 2017-07-28_Seat_Leon_KA_RT_Stau.csv
# 2017-07-31_Seat_Leon_KA_KA_Frei.csv
# 2017-08-08_Seat_Leon_RT_S_Normal.csv
# 2017-08-07_Seat_Leon_RT_KA_Frei_Vollbremsung.csv
# 2018-03-22_Seat_Leon_S_RT_Normal.csv
# 2018-02-17_Seat_Leon_RT_BB_Frei.csv
# 2018-02-21_Seat_Leon_BB_RT_Normal.csv
# 2017-07-27_Seat_Leon_KA_KA_Normal.csv
# 2017-07-05_Seat_Leon_RT_S_Stau.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(12,5))
#       4 plt.plot(df["Engine RPM [RPM]"])
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.figure(figsize=(12,5))
plt.plot(df["Vehicle Speed Sensor [km/h]"])
plt.title("Vehicle Speed")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.figure(figsize=(12,5))
#       2 plt.plot(df["Vehicle Speed Sensor [km/h]"])
#       3 plt.title("Vehicle Speed")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# !pip install matplotlib
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 14.7 MB/s  0:00:00 13.4 MB/s eta 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 7.3 MB/s  0:00:0021.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 16.7 MB/s  0:00:009.7 MB/s eta 0:00:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["Engine RPM [RPM]"])
plt.title("Engine RPM")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df["Vehicle Speed Sensor [km/h]"])
plt.title("Vehicle Speed")
plt.show()

# %%
corr = df.corr(numeric_only=True)

corr
# Out:
#                                            Engine Coolant Temperature [Â°C]  \
# Engine Coolant Temperature [Â°C]                                   1.000000
# Intake Manifold Absolute Pressure [kPa]                            0.142669
# Engine RPM [RPM]                                                   0.194049
# Vehicle Speed Sensor [km/h]                                        0.238401
# Intake Air Temperature [Â°C]                                       0.025766
# Air Flow Rate from Mass Flow Sensor [g/s]                          0.130891
# Absolute Throttle Position [%]                                    -0.009332
# Ambient Air Temperature [Â°C]                                      0.226606
# Accelerator Pedal Position D [%]                                  -0.040106
# Accelerator Pedal Position E [%]                                  -0.038900
#
#                                            Intake Manifold Absolute Pressure [kPa]  \
# ...
